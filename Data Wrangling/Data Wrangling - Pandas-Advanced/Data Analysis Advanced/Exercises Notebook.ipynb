# %% [markdown]
# # options

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Exercise 0 - Read the data
#
# the file is under the folder data and is named `supermarket_sales_V2.csv`

# %%
df = pd.read_csv(os.path.join('data', 'supermarket_sales_V2.csv'))
df.head(3)
df.shape
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity      Date   Time      Payment  \
# 0       Health and beauty       74.69         7  1/5/2019  13:08      Ewallet
# 1  Electronic accessories       15.28         5  3/8/2019  10:29         Cash
# 2      Home and lifestyle       46.33         7  3/3/2019  13:23  Credit card
#
#      cogs  Rating
# 0  522.83     9.1
# 1   76.40     9.6
# 2  324.31     7.4
# (1000, 13)

# %% [markdown]
# This data contains the necessary info to compute the remaining columns:

# %% [markdown]
# # Exercise 1 - Creating new columns

# %% [markdown]
# ## Exercise 1.1
#
# create a new column `Total (Before Taxes)` that represents the cost of the purchase before taxes obtained by multiplying the `quantity` by the `unit price`

# %%
df['Total (Before Taxes)'] = df.Quantity * df['Unit price']
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment    cogs  Rating  Total (Before Taxes)
# 0      Ewallet  522.83     9.1                522.83
# 1         Cash   76.40     9.6                 76.40
# 2  Credit card  324.31     7.4                324.31
# 3      Ewallet  465.76     8.4                465.76
# 4      Ewallet  604.17     5.3                604.17

# %% [markdown]
# ## Exercise 1.2
#
# > Create a new column `Tax 7%` that represents a 7% of the `Total (Before Taxes)`

# %%
df['Tax 7%'] = df['Total (Before Taxes)'] * 0.07
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment    cogs  Rating  Total (Before Taxes)   Tax 7%
# 0      Ewallet  522.83     9.1                522.83  36.5981
# 1         Cash   76.40     9.6                 76.40   5.3480
# 2  Credit card  324.31     7.4                324.31  22.7017
# 3      Ewallet  465.76     8.4                465.76  32.6032
# 4      Ewallet  604.17     5.3                604.17  42.2919

# %% [markdown]
# ## Exercise 1.3
# > Create a new column `Total` that represents the `Total (Before Taxes)` added with the `Tax 7%`

# %%
df['Total'] = df['Total (Before Taxes)'] + df['Tax 7%']
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment    cogs  Rating  Total (Before Taxes)   Tax 7%     Total
# 0      Ewallet  522.83     9.1                522.83  36.5981  559.4281
# 1         Cash   76.40     9.6                 76.40   5.3480   81.7480
# 2  Credit card  324.31     7.4                324.31  22.7017  347.0117
# 3      Ewallet  465.76     8.4                465.76  32.6032  498.3632
# 4      Ewallet  604.17     5.3                604.17  42.2919  646.4619

# %% [markdown]
# ## Exercise 1.4
# > Create a new column `gross income` that represents the Total minus the cost of goods sold `cogs`

# %%
df['gross income'] = df.Total - df.cogs
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment    cogs  Rating  Total (Before Taxes)   Tax 7%     Total  \
# 0      Ewallet  522.83     9.1                522.83  36.5981  559.4281
# 1         Cash   76.40     9.6                 76.40   5.3480   81.7480
# 2  Credit card  324.31     7.4                324.31  22.7017  347.0117
# 3      Ewallet  465.76     8.4                465.76  32.6032  498.3632
# 4      Ewallet  604.17     5.3                604.17  42.2919  646.4619
#
#    gross income
# 0       36.5981
# 1        5.3480
# 2       22.7017
# 3       32.6032
# 4       42.2919

# %% [markdown]
# ## Exercise 1.5
# > Create a new column `gross margin percentage` that represents the `gross income` as a percentage of the `Total`

# %%
df['gross margin percentage'] = (df['gross income'] / df.Total) * 100
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment    cogs  Rating  Total (Before Taxes)   Tax 7%     Total  \
# 0      Ewallet  522.83     9.1                522.83  36.5981  559.4281
# 1         Cash   76.40     9.6                 76.40   5.3480   81.7480
# 2  Credit card  324.31     7.4                324.31  22.7017  347.0117
# 3      Ewallet  465.76     8.4                465.76  32.6032  498.3632
# 4      Ewallet  604.17     5.3                604.17  42.2919  646.4619
#
#    gross income  gross margin percentage
# 0       36.5981                 6.542056
# 1        5.3480                 6.542056
# 2       22.7017                 6.542056
# 3       32.6032                 6.542056
# 4       42.2919                 6.542056

# %% [markdown]
# ## Exercise 1.6
# > Create a new column `hour` that is the hour of the day extracted from the column `Time`

# %%
df['hour'] = df['Time'].apply(lambda row: int(row.split(':')[0]))
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment    cogs  Rating  Total (Before Taxes)   Tax 7%     Total  \
# 0      Ewallet  522.83     9.1                522.83  36.5981  559.4281
# 1         Cash   76.40     9.6                 76.40   5.3480   81.7480
# 2  Credit card  324.31     7.4                324.31  22.7017  347.0117
# 3      Ewallet  465.76     8.4                465.76  32.6032  498.3632
# 4      Ewallet  604.17     5.3                604.17  42.2919  646.4619
#
#    gross income  gross margin percentage  hour
# 0       36.5981                 6.542056    13
# 1        5.3480                 6.542056    10
# 2       22.7017                 6.542056    13
# 3       32.6032                 6.542056    20
# 4       42.2919                 6.542056    10

# %% [markdown]
# # Exercise 2 - Masking

# %% [markdown]
# ## Exercise 2.1
# > What is the median payment gross income the supermarket company has from men?

# %%
men_mask = df.loc[df['Gender'] == 'Male',:]
gross_income_from_men = men_mask['gross income']
gross_income_from_men.median()
men_mask.head()
# Out:
# np.float64(16.28200000000001)
#      Invoice ID Branch       City Customer type Gender  \
# 2   631-41-3108      A     Yangon        Normal   Male
# 3   123-19-1176      A     Yangon        Member   Male
# 4   373-73-7910      A     Yangon        Normal   Male
# 5   699-14-3026      C  Naypyitaw        Normal   Male
# 11  529-56-3974      B   Mandalay        Member   Male
#
#               Product line  Unit price  Quantity       Date   Time  \
# 2       Home and lifestyle       46.33         7   3/3/2019  13:23
# 3        Health and beauty       58.22         8  1/27/2019  20:33
# 4        Sports and travel       86.31         7   2/8/2019  10:37
# 5   Electronic accessories       85.39         7  3/25/2019  18:30
# 11  Electronic accessories       25.51         4   3/9/2019  17:03
#
#         Payment    cogs  Rating  Total (Before Taxes)   Tax 7%     Total  \
# 2   Credit card  324.31     7.4                324.31  22.7017  347.0117
# 3       Ewallet  465.76     8.4                465.76  32.6032  498.3632
# 4       Ewallet  604.17     5.3                604.17  42.2919  646.4619
# 5       Ewallet  597.73     4.1                597.73  41.8411  639.5711
# 11         Cash  102.04     6.8                102.04   7.1428  109.1828
#
#     gross income  gross margin percentage  hour
# 2        22.7017                 6.542056    13
# 3        32.6032                 6.542056    20
# 4        42.2919                 6.542056    10
# 5        41.8411                 6.542056    18
# 11        7.1428                 6.542056    17

# %% [markdown]
# ## Exercise 2.2
# > How many purchases does the store in City `Mandalay` have?

# %%
mandalay_mask = df.loc[df['City'] == 'Mandalay', :]
n_purchases_mandalay = mandalay_mask.shape[1]
n_purchases_mandalay
# Out:
# 19

# %% [markdown]
# ## Exercise 2.3
#
# > What is the average rating of `Member` costumers in the store `Yagon`

# %%
yagon_mask = df.loc[df['City'] == 'Yangon', :]
yagon_mask.head()
avg_rating_member_yagon = yagon_mask.groupby('Customer type')['Rating'].mean()['Member']
avg_rating_member_yagon
# Out:
#     Invoice ID Branch    City Customer type  Gender            Product line  \
# 0  750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2  631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4  373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6  355-53-5943      A  Yangon        Member  Female  Electronic accessories
#
#    Unit price  Quantity       Date   Time      Payment    cogs  Rating  \
# 0       74.69         7   1/5/2019  13:08      Ewallet  522.83     9.1
# 2       46.33         7   3/3/2019  13:23  Credit card  324.31     7.4
# 3       58.22         8  1/27/2019  20:33      Ewallet  465.76     8.4
# 4       86.31         7   2/8/2019  10:37      Ewallet  604.17     5.3
# 6       68.84         6  2/25/2019  14:36      Ewallet  413.04     5.8
#
#    Total (Before Taxes)   Tax 7%     Total  gross income  \
# 0                522.83  36.5981  559.4281       36.5981
# 2                324.31  22.7017  347.0117       22.7017
# 3                465.76  32.6032  498.3632       32.6032
# 4                604.17  42.2919  646.4619       42.2919
# 6                413.04  28.9128  441.9528       28.9128
#
#    gross margin percentage  hour
# 0                 6.542056    13
# 2                 6.542056    13
# 3                 6.542056    20
# 4                 6.542056    10
# 6                 6.542056    14
# np.float64(6.99880239520958)

# %% [markdown]
# ## Exercise 2.4
# what is the `Invoice ID` of the the most expensive purchase (`Total`) made in the morning (in other words: until, not including, 12 o´clock)

# %%
df.loc[df.loc[df['hour'] < 12,:]['Total'].idxmax()]['Invoice ID']
invoice_id = df.iloc[df.loc[df['hour'] < 12,:]['Total'].idxmax()]['Invoice ID']
# Out:
# '325-77-6186'

# %% [markdown]
# ## Exercise 2.5
# > What is the product line `Women` buy most often at night (between 19h and 24h, all inclusive)

# %%
pline_most_women_night = df.loc[(df['hour'] >= 19) & (df['hour'] <= 24) & (df['Gender'] == 'Female'), :]['Product line'].value_counts().idxmax()
pline_most_women_night
# Out:
# 'Food and beverages'

# %% [markdown]
# ## Exercise 2.6
# > How many purchases were made by women in both `Health and beauty` and `Home and Lifestyle` `Product lines`?

# %%
npurchases = df.loc[(df['Gender'] == 'Female') & (df['Product line'].isin(['Health and beauty', 'Home and lifestyle']))].shape[0]
npurchases # n_purchases =
# Out:
# 143

# %% [markdown]
# # Exercise 3 - Groupbys

# %% [markdown]
# ## Exercise 3.1
# > what is the average `Total` by gender?

# %%
df.groupby('Gender')['Total'].mean()
# Out:
# Gender
# Female    341.478433
# Male      316.709021
# Name: Total, dtype: float64

# %% [markdown]
# ## Exercise 3.1 b)
# > use a bar plot to show the previous result

# %%
df.groupby('Gender')['Total'].mean().plot.bar()
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# ## Exercise 3.2
# > What is the average Rating by City?

# %%
df.groupby('City')['Rating'].mean()# ...
# Out:
# City
# Mandalay     6.818072
# Naypyitaw    7.072866
# Yangon       7.027059
# Name: Rating, dtype: float64

# %% [markdown]
# ## Exercise 3.2 b)
# > use a bar plot to show the previous result

# %%
df.groupby('City')['Rating'].mean().plot.bar()
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# ## Exercise 3.3
# > What is the `Product line` that sells most items (i.e. `Quantities`)

# %%
df.groupby('Product line')['Quantity'].sum().idxmax()
# Out:
# 'Electronic accessories'

# %% [markdown]
# ## Exercise 3.4
# > What is the activity of customers throughout the day?
#
# Compute the number of invoices at each hour of the day

# %%
df.groupby('hour')['Invoice ID'].count()
# Out:
# hour
# 10    101
# 11     90
# 12     89
# 13    103
# 14     83
# 15    102
# 16     77
# 17     74
# 18     93
# 19    113
# 20     75
# Name: Invoice ID, dtype: int64

# %% [markdown]
# ## Exercise 3.4 b)
# > use a bar plot to show the previous result

# %%
df.groupby('hour')['Invoice ID'].count().plot.bar()
# Out:
# <Axes: xlabel='hour'>

# %% [markdown]
# ## Exercise 3.5
# > For each city, what is the `Invoice ID` of the highest `gross margin` sale?

# %%
df.head()
highest_invoice_id = df.loc[df.groupby('City')['gross margin percentage'].idxmax(), ['City', 'Invoice ID']]
highest_invoice_id
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment    cogs  Rating  Total (Before Taxes)   Tax 7%     Total  \
# 0      Ewallet  522.83     9.1                522.83  36.5981  559.4281
# 1         Cash   76.40     9.6                 76.40   5.3480   81.7480
# 2  Credit card  324.31     7.4                324.31  22.7017  347.0117
# 3      Ewallet  465.76     8.4                465.76  32.6032  498.3632
# 4      Ewallet  604.17     5.3                604.17  42.2919  646.4619
#
#    gross income  gross margin percentage  hour
# 0       36.5981                 6.542056    13
# 1        5.3480                 6.542056    10
# 2       22.7017                 6.542056    13
# 3       32.6032                 6.542056    20
# 4       42.2919                 6.542056    10
#           City   Invoice ID
# 342   Mandalay  873-95-4984
# 723  Naypyitaw  592-46-1692
# 37      Yangon  272-65-1806

# %% [markdown]
# ## Exercise 3.6
#
# > For each customer type, what is the average gross margin on each Product line?
#
# Try passing a list of columns to the `.groupby` method, and compute the average `gross margin` of that groupby

# %%
avg_gm_costumer_type = df.groupby(['Customer type', 'Product line'])['gross margin percentage'].mean()
avg_gm_costumer_type
# Out:
# Customer type  Product line
# Member         Electronic accessories    6.542056
#                Fashion accessories       6.542056
#                Food and beverages        6.542056
#                Health and beauty         6.542056
#                Home and lifestyle        6.542056
#                Sports and travel         6.542056
# Normal         Electronic accessories    6.542056
#                Fashion accessories       6.542056
#                Food and beverages        6.542056
#                Health and beauty         6.542056
#                Home and lifestyle        6.542056
#                Sports and travel         6.542056
# Name: gross margin percentage, dtype: float64
